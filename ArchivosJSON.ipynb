# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install pyctcdecode
# !pip install https://github.com/kpu/kenlm/archive/master.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached https://github.com/kpu/kenlm/archive/master.zip

# %%
# !pip install lightning-flash
# !pip install 'lightning-flash[audio]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install folium==0.2.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import json
import torch
import flash
from flash.audio import SpeechRecognition, SpeechRecognitionData

# %% [markdown]
# #TIC TAC TOE

# %%
#Los Links que salen tanto en columnas como filas varian del drive de la persona
columnas = ["/content/drive/MyDrive/OctavoCiclo/TDP/speechrecognition/CertificationTest/a.wav","/content/drive/MyDrive/OctavoCiclo/TDP/speechrecognition/CertificationTest/be.wav","/content/drive/MyDrive/OctavoCiclo/TDP/speechrecognition/CertificationTest/ce.wav"]
index = 0

data_json = [[],[]]
# 0 is columns and 1 is rows
model = SpeechRecognition.load_from_checkpoint("/content/drive/MyDrive/OctavoCiclo/TDP/modelo/Modelo_30ep_thirdTrain_part2.pt")
trainer = flash.Trainer()

for k in columnas:
  datamodule = SpeechRecognitionData.from_files(predict_files=[k], batch_size=4)
  predictions = trainer.predict(model, datamodule=datamodule)
  data_json[0].append({"value":index,"key":predictions[0][0]})
  index = index + 1

#Los Links que salen tanto en columnas como filas varian del drive de la persona
filas = ["/content/drive/MyDrive/OctavoCiclo/TDP/speechrecognition/CertificationTest/uno.wav","/content/drive/MyDrive/OctavoCiclo/TDP/speechrecognition/CertificationTest/dos.wav","/content/drive/MyDrive/OctavoCiclo/TDP/speechrecognition/CertificationTest/tres.wav"]
index = 0
for k in filas:
	datamodule = SpeechRecognitionData.from_files(predict_files=[k], batch_size=4)
	predictions = trainer.predict(model, datamodule=datamodule)
	data_json[1].push({"value":index,"key":predictions[0][0]})
	index = index + 3

json_object = json.dumps(data_json, indent = 4) 
print (json_object)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 'jonatasgrosman/wav2vec2-large-xlsr-53-spanish' provided by Hugging Face/transformers (https://github.com/huggingface/transformers).

# %%
data_json = [[],[]]
# 0 is columns and 1 is rows
model = SpeechRecognition.load_from_checkpoint("/content/drive/MyDrive/OctavoCiclo/TDP/modelo/Modelo_30ep_thirdTrain_part2.pt")
trainer = flash.Trainer()

#Los Links que salen tanto en columnas como filas varian del drive de la persona
filas = ["/content/drive/MyDrive/OctavoCiclo/TDP/speechrecognition/CertificationTest/uno.wav","/content/drive/MyDrive/OctavoCiclo/TDP/speechrecognition/CertificationTest/dos.wav","/content/drive/MyDrive/OctavoCiclo/TDP/speechrecognition/CertificationTest/tres.wav"]
index = 0
for k in filas:
	datamodule = SpeechRecognitionData.from_files(predict_files=[k], batch_size=4)
	predictions = trainer.predict(model, datamodule=datamodule)
	data_json[1].append({"value":index,"key":predictions[0][0]})
	index = index + 3

json_object = json.dumps(data_json, indent = 4) 
print (json_object)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Using 'jonatasgrosman/wav2vec2-large-xlsr-53-spanish' provided by Hugging Face/transformers (https://github.com/huggingface/transformers).
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# [
#     [],
#     [
#         {
#             "value": 0,
#             "key": "uno"
#         },
#         {
#             "value": 3,
#             "key": "tdos"
#         },
#         {
#             "value": 6,
#             "key": "tres"
#         }
#     ]
# ]

# %% [markdown]
# #DAMAS

# %%
columnas = ["/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/a.wav","/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/b.wav","/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/c.wav"]
index = 0

data_json["columnas"] = []
data_json["filas"] = []
for k in columnas:
	datamodule = SpeechRecognitionData.from_files(predict_files=[k], batch_size=4)
	predictions = trainer.predict(model, datamodule=datamodule)
	data_json["columnas"].push({"value":index,"key":predictions[0][0]})
	index++

filas = ["/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/a.wav","/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/b.wav","/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/c.wav"]
index = 0
for k in filas:
	datamodule = SpeechRecognitionData.from_files(predict_files=[k], batch_size=4)
	predictions = trainer.predict(model, datamodule=datamodule)
	data_json["filas"].push({"value":index,"key":predictions[0][0]})
	index+=3

json_object = json.dumps(data_json, indent = 4) 
print (json_object)

# %% [markdown]
# #MEMORIA

# %%
columnas = ["/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/a.wav","/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/b.wav","/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/c.wav"]
index = 0

data_json["columnas"] = []
data_json["filas"] = []
for k in columnas:
	datamodule = SpeechRecognitionData.from_files(predict_files=[k], batch_size=4)
	predictions = trainer.predict(model, datamodule=datamodule)
	data_json["columnas"].push({"value":index,"key":predictions[0][0]})
	index++

filas = ["/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/a.wav","/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/b.wav","/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/c.wav"]
index = 0
for k in filas:
	datamodule = 
	SpeechRecognitionData.from_files(predict_files=[k], batch_size=4)
	predictions = trainer.predict(model, datamodule=datamodule)
	data_json["filas"].push({"value":index,"key":predictions[0][0]})
	index+=3

json_object = json.dumps(data_json, indent = 4) 
print (json_object)

# %% [markdown]
# #MENU

# %%
columnas = ["/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/a.wav","/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/b.wav","/content/drive/MyDrive/UPC/TP1/speechrecognition/CertificacionTest/c.wav"]
index = 0

data_json["pausa"] = ""
data_json["reiniciar"] = ""
data_json["cerrar"] = ""
data_json["reanudar"] = ""
for k in columnas:
	datamodule = SpeechRecognitionData.from_files(predict_files=[k], batch_size=4)
	predictions = trainer.predict(model, datamodule=datamodule)
	data_json[predictions[0][0]].push({"value":index,"key":predictions[0][0]})

json_object = json.dumps(data_json, indent = 4) 
print (json_object)
